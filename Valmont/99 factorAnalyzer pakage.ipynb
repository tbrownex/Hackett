# %% [markdown]
# ##### Create some test data with mean=0 and stdDev=1.0

# %%
rows = 100
cols = 20
tm.N = rows
tm.K = cols

df = tm.makeDataFrame()
x = [x for x in range(rows)]
df.index=x

# Here are the first 5 rows
df.head()
# Out:
#           A         B         C         D         E         F         G  \
# 0  1.096606 -0.263071  1.950228 -0.616639 -0.759178  0.504519  2.467393
# 1 -1.561886  2.081268 -0.572404  0.410805  0.760514  1.529157  0.657727
# 2  0.150929  1.489105  0.774906  0.576417  0.477904  1.727845  0.369705
# 3  0.784248 -0.021723  0.223220  0.688417  0.650573 -0.566146  0.991747
# 4  1.359370 -2.039269 -0.538055  0.330441  1.155280 -0.258783  0.968644
#
#           H         I         J         K         L         M         N  \
# 0  0.724955 -0.833960 -1.305027 -0.381730  0.922268  1.272660  0.644595
# 1  0.688868 -0.788486 -0.301661  0.691919 -1.284826 -1.724592 -0.416671
# 2  1.334072 -1.101207  2.503235 -0.420711 -0.942370 -0.089493 -0.469425
# 3  0.950820  0.773550  0.416433 -0.976000 -0.087550  0.273250  0.000753
# 4 -0.236284  0.040904  1.197598 -0.164752 -0.612500 -1.165849  1.120324
#
#           O         P         Q         R         S         T
# ...

# %% [markdown]
# ##### Look at the correlation matrix

# %%
df.corr()     # Should see nothing higher than about 0.25
# Out:
#           A         B         C         D         E         F         G  \
# A  1.000000  0.055498  0.143128 -0.093236 -0.104172  0.133259 -0.054147
# B  0.055498  1.000000  0.079135 -0.236071  0.000851 -0.046927 -0.066417
# C  0.143128  0.079135  1.000000 -0.036313 -0.024601  0.039943  0.115229
# D -0.093236 -0.236071 -0.036313  1.000000  0.081851 -0.002982  0.081109
# E -0.104172  0.000851 -0.024601  0.081851  1.000000 -0.016798 -0.059044
# F  0.133259 -0.046927  0.039943 -0.002982 -0.016798  1.000000  0.066916
# G -0.054147 -0.066417  0.115229  0.081109 -0.059044  0.066916  1.000000
# H  0.232755  0.199712 -0.007398 -0.122255  0.016423 -0.095933  0.027569
# I -0.055202  0.019713 -0.005359  0.097348  0.092680 -0.172330  0.098738
# J -0.037960 -0.029974 -0.020846 -0.059413 -0.067127 -0.040007 -0.185572
#
#           H         I         J
# A  0.232755 -0.055202 -0.037960
# B  0.199712  0.019713 -0.029974
# C -0.007398 -0.005359 -0.020846
# D -0.122255  0.097348 -0.059413
# ...

# %% [markdown]
# ##### Now create a strong correlation between two columns:  D = C + noise

# %%
#The noise is mean=0 stdDev=1.0
df["D"] = df["C"]+pd.Series([np.random.randn() for x in range(rows)])

# and see if the correlation matrix changed
# "C" and "D" should be about 0.75
df.corr()
# Out:
#           A         B         C         D         E         F         G  \
# A  1.000000  0.055498  0.143128 -0.002738 -0.104172  0.133259 -0.054147
# B  0.055498  1.000000  0.079135  0.119405  0.000851 -0.046927 -0.066417
# C  0.143128  0.079135  1.000000  0.667848 -0.024601  0.039943  0.115229
# D -0.002738  0.119405  0.667848  1.000000  0.045299  0.064773  0.042606
# E -0.104172  0.000851 -0.024601  0.045299  1.000000 -0.016798 -0.059044
# F  0.133259 -0.046927  0.039943  0.064773 -0.016798  1.000000  0.066916
# G -0.054147 -0.066417  0.115229  0.042606 -0.059044  0.066916  1.000000
# H  0.232755  0.199712 -0.007398 -0.022388  0.016423 -0.095933  0.027569
# I -0.055202  0.019713 -0.005359  0.064807  0.092680 -0.172330  0.098738
# J -0.037960 -0.029974 -0.020846 -0.049388 -0.067127 -0.040007 -0.185572
#
#           H         I         J
# A  0.232755 -0.055202 -0.037960
# B  0.199712  0.019713 -0.029974
# C -0.007398 -0.005359 -0.020846
# D -0.022388  0.064807 -0.049388
# ...

# %%
from factor_analyzer import FactorAnalyzer

# %%
fa = FactorAnalyzer()

# %%
fa.analyze(df, 5, rotation=None, use_scaling=False)

# %%
fa.loadings
# Out:
#     Factor1   Factor2   Factor3   Factor4   Factor5
# A  0.114184  0.034997 -0.084953  0.380798 -0.271002
# B  0.102736 -0.149329 -0.026050  0.208505  0.057186
# C  0.791289 -0.171112 -0.100211 -0.040721 -0.172196
# D  0.808264 -0.209581 -0.157243 -0.107125  0.159324
# E -0.005559 -0.063276 -0.010706 -0.029934  0.332857
# F  0.235104  0.870698 -0.356077  0.201553  0.120749
# G  0.316964  0.370833  0.865362 -0.090376 -0.049258
# H  0.029512 -0.221828  0.195483  0.736190  0.089055
# I  0.029261 -0.156210  0.176074 -0.008362  0.195305
# J -0.098311 -0.047418 -0.175076 -0.137493 -0.135098

# %%
fa.get_uniqueness()
# Out:
#    Uniqueness
# A    0.760071
# B    0.919723
# C    0.303231
# D    0.241199
# E    0.884161
# F    0.004617
# G    0.002571
# H    0.361802
# I    0.905526
# J    0.920279
