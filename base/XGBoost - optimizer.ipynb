# %%
results.corr()
# Out:
#                   colsample_bytree  learning_rate  max_depth  n_estimators  \
# colsample_bytree          1.000000      -0.007967  -0.008250           NaN
# learning_rate            -0.007967       1.000000  -0.011701           NaN
# max_depth                -0.008250      -0.011701   1.000000           NaN
# n_estimators                   NaN            NaN        NaN           NaN
# random_state                   NaN            NaN        NaN           NaN
# score                    -0.344913       0.114517  -0.635983           NaN
# subsample                -0.006890      -0.009772  -0.010119           NaN
#
#                   random_state     score  subsample
# colsample_bytree           NaN -0.344913  -0.006890
# learning_rate              NaN  0.114517  -0.009772
# max_depth                  NaN -0.635983  -0.010119
# n_estimators               NaN       NaN        NaN
# random_state               NaN       NaN        NaN
# score                      NaN  1.000000  -0.104759
# ...

# %%
results.sort_values('score')
# Out:
#     colsample_bytree  learning_rate  max_depth  n_estimators  random_state  \
# 0                1.0         0.0900         12           300          1919
# 0                1.0         0.1425         12           300          1919
# 0                1.0         0.1950         12           300          1919
# 0                1.0         0.0900         12           300          1919
# 0                1.0         0.2475         12           300          1919
# 0                1.0         0.3000         12           300          1919
# 0                1.0         0.1425         12           300          1919
# 0                1.0         0.0900         10           300          1919
# 0                1.0         0.1950         12           300          1919
# 0                1.0         0.1425         10           300          1919
# 0                1.0         0.0900         10           300          1919
# ...
