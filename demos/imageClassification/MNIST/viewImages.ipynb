# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
def getData():
    train, test = tf.keras.datasets.mnist.load_data()
    return train, test

# %%
train, test = getData()
trainX, trainY = train
testX, testY   = test

# %%
def showImage(trainX, trainY, x):
    print(trainX[x].shape)
    plt.imshow(trainX[x], cmap='Greys')
    title = "Labeled as: "+ str(trainY[x])
    plt.title(title)
    plt.show()

# %%
while True:
    imageNum = input("Enter a number between 1 and 40,000")
    showImage(trainX, trainY, int(imageNum))
# Out:
# Enter a number between 1 and 40,0003
# (28, 28)
# Enter a number between 1 and 40,00011
# (28, 28)
# Enter a number between 1 and 40,00044
# (28, 28)
# Enter a number between 1 and 40,00044
# (28, 28)
