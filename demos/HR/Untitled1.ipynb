# %%
from getConfig import getConfig
from getData import getData

config = getConfig()
df     = getData(config)

# %%
df.describe()
# Out:
#              Gender  University Prestige        Degree  Left Company  \
# count  15000.000000         15000.000000  15000.000000  15000.000000
# mean      -0.102800             1.965133      0.651667     -0.500000
# std        0.994735             1.692053      0.476458      0.866054
# min       -1.000000             0.000000      0.000000     -1.000000
# 25%       -1.000000             0.000000      0.000000     -1.000000
# 50%       -1.000000             2.000000      1.000000     -1.000000
# 75%        1.000000             3.000000      1.000000     -0.500000
# max        1.000000             5.000000      1.000000      1.000000
#
#        Industry Yrs      Role Yrs  Current Job Level  \
# count  15000.000000  15000.000000       15000.000000
# mean      11.946733     11.960333           3.007333
# std        7.232661      7.203052           1.093630
# min        0.000000      0.000000           1.000000
# 25%        6.000000      6.000000           2.000000
# ...

# %%
df.head()
# Out:
#    Gender  University Prestige  Degree  Left Company  Industry Yrs  Role Yrs  \
# 0      -1                    3       1            -1            10         9
# 1       1                    0       0            -1             5        23
# 2      -1                    0       0            -1            14         7
# 3       1                    0       0            -1             6        10
# 4       1                    2       1            -1            11         0
#
#    Current Job Level  Yrs Since Last Promotion  Engagement_1  Engagement_2  \
# 0                  4                         3             3             3
# 1                  4                         3             4             4
# 2                  3                         2             3             4
# 3                  3                         3             3             2
# 4                  4                         3             4             1
#
# ...
